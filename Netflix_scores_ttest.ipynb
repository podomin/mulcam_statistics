# %% [markdown]
# ## t-test 연습 2.
#
# 데이터 셋: https://www.kaggle.com/datasets/luiscorter/netflix-original-films-imdb-scores
#
# 위 데이터 셋은 넷플릭스 오리지널 시리즈의 메타 데이터와 평점을 담은 데이터 셋입니다. 지금까지 배운 시각화와 통계 기법들을 활용하여 넷플릭스의 데이터 분석가가 되었다고 생각하고 데이터를 통해서 인사이트를 전달해보세요.
#
# ![image.png](attachment:56cb8dd8-2b04-4bd7-b7ac-b10facce351f.png)
#
# ## 요구 사항
# - 기본적인 EDA와 시각화를 해주세요.
# - t-test 기법을 다양하게 사용해보세요.
# - 통계적 근거를 활용하여 오리지널 시리즈 제작 방향에 대한 제언을 해보세요.
# - 결과물을 velog에 기록해주세요. (선택)

# %% [markdown]
# ## EDA

# %% [markdown]
# ## 데이터 불러오기

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# pd.read_csv("./data/NetflixOriginals.csv", encoding="latin1")
df = pd.read_csv("./data/NetflixOriginals.csv", encoding="ISO-8859-1")
df
# Out:
#                                            Title                  Genre  \
# 0                                Enter the Anime            Documentary
# 1                                    Dark Forces               Thriller
# 2                                        The App  Science fiction/Drama
# 3                                 The Open House        Horror thriller
# 4                                    Kaali Khuhi                Mystery
# ..                                           ...                    ...
# 579        Taylor Swift: Reputation Stadium Tour           Concert Film
# 580  Winter on Fire: Ukraine's Fight for Freedom            Documentary
# 581                      Springsteen on Broadway           One-man show
# 582    Emicida: AmarElo - It's All For Yesterday            Documentary
# 583     David Attenborough: A Life on Our Planet            Documentary
#
#               Premiere  Runtime  IMDB Score                  Language
# 0       August 5, 2019       58         2.5          English/Japanese
# 1      August 21, 2020       81         2.6                   Spanish
# 2    December 26, 2019       79         2.6                   Italian
# 3     January 19, 2018       94         3.2                   English
# 4     October 30, 2020       90         3.4                     Hindi
# ..                 ...      ...         ...                       ...
# 579  December 31, 2018      125         8.4                   English
# 580    October 9, 2015       91         8.4  English/Ukranian/Russian
# 581  December 16, 2018      153         8.5                   English
# 582   December 8, 2020       89         8.6                Portuguese
# 583    October 4, 2020       83         9.0                   English
#
# [584 rows x 6 columns]

# %%
df.shape
# Out:
# (584, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 584 entries, 0 to 583
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Title       584 non-null    object
#  1   Genre       584 non-null    object
#  2   Premiere    584 non-null    object
#  3   Runtime     584 non-null    int64
#  4   IMDB Score  584 non-null    float64
#  5   Language    584 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 27.5+ KB

# %%
df.isnull().sum()
# Out:
# Title         0
# Genre         0
# Premiere      0
# Runtime       0
# IMDB Score    0
# Language      0
# dtype: int64

# %%
df.describe()
# Out:
#           Runtime  IMDB Score
# count  584.000000  584.000000
# mean    93.577055    6.271747
# std     27.761683    0.979256
# min      4.000000    2.500000
# 25%     86.000000    5.700000
# 50%     97.000000    6.350000
# 75%    108.000000    7.000000
# max    209.000000    9.000000

# %%
df.columns
# Out:
# Index(['Title', 'Genre', 'Premiere', 'Runtime', 'IMDB Score', 'Language'], dtype='object')

# %% [markdown]
# ### 날짜 나누기 + 맵핑

# %%
df['Premiere'] = pd.to_datetime(df['Premiere'], format='mixed')
df
# Out:
#                                            Title                  Genre  \
# 0                                Enter the Anime            Documentary
# 1                                    Dark Forces               Thriller
# 2                                        The App  Science fiction/Drama
# 3                                 The Open House        Horror thriller
# 4                                    Kaali Khuhi                Mystery
# ..                                           ...                    ...
# 579        Taylor Swift: Reputation Stadium Tour           Concert Film
# 580  Winter on Fire: Ukraine's Fight for Freedom            Documentary
# 581                      Springsteen on Broadway           One-man show
# 582    Emicida: AmarElo - It's All For Yesterday            Documentary
# 583     David Attenborough: A Life on Our Planet            Documentary
#
#       Premiere  Runtime  IMDB Score                  Language
# 0   2019-08-05       58         2.5          English/Japanese
# 1   2020-08-21       81         2.6                   Spanish
# 2   2019-12-26       79         2.6                   Italian
# 3   2018-01-19       94         3.2                   English
# 4   2020-10-30       90         3.4                     Hindi
# ..         ...      ...         ...                       ...
# 579 2018-12-31      125         8.4                   English
# 580 2015-10-09       91         8.4  English/Ukranian/Russian
# 581 2018-12-16      153         8.5                   English
# 582 2020-12-08       89         8.6                Portuguese
# 583 2020-10-04       83         9.0                   English
#
# [584 rows x 6 columns]

# %%
df['month'] = df['Premiere'].dt.month
df['year'] = df['Premiere'].dt.year
df['day'] = df['Premiere'].dt.dayofweek
df['date_day'] = df['Premiere'].dt.day
df
# Out:
#                                            Title                  Genre  \
# 0                                Enter the Anime            Documentary
# 1                                    Dark Forces               Thriller
# 2                                        The App  Science fiction/Drama
# 3                                 The Open House        Horror thriller
# 4                                    Kaali Khuhi                Mystery
# ..                                           ...                    ...
# 579        Taylor Swift: Reputation Stadium Tour           Concert Film
# 580  Winter on Fire: Ukraine's Fight for Freedom            Documentary
# 581                      Springsteen on Broadway           One-man show
# 582    Emicida: AmarElo - It's All For Yesterday            Documentary
# 583     David Attenborough: A Life on Our Planet            Documentary
#
#       Premiere  Runtime  IMDB Score                  Language  month  year  \
# 0   2019-08-05       58         2.5          English/Japanese      8  2019
# 1   2020-08-21       81         2.6                   Spanish      8  2020
# 2   2019-12-26       79         2.6                   Italian     12  2019
# 3   2018-01-19       94         3.2                   English      1  2018
# 4   2020-10-30       90         3.4                     Hindi     10  2020
# ..         ...      ...         ...                       ...    ...   ...
# 579 2018-12-31      125         8.4                   English     12  2018
# 580 2015-10-09       91         8.4  English/Ukranian/Russian     10  2015
# 581 2018-12-16      153         8.5                   English     12  2018
# 582 2020-12-08       89         8.6                Portuguese     12  2020
# 583 2020-10-04       83         9.0                   English     10  2020
#
#      day  date_day
# 0      0         5
# 1      4        21
# 2      3        26
# 3      4        19
# 4      4        30
# ..   ...       ...
# 579    0        31
# 580    4         9
# 581    6        16
# 582    1         8
# 583    6         4
#
# [584 rows x 10 columns]

# %%
dmap = {0: 'Mon',1:'Tues',2:'Wed',3:'Thurs',4:'Fri',5:'Sat',6:'Sun'}
df['day of week'] = df['day'].map(dmap)
df
# Out:
#                                            Title                  Genre  \
# 0                                Enter the Anime            Documentary
# 1                                    Dark Forces               Thriller
# 2                                        The App  Science fiction/Drama
# 3                                 The Open House        Horror thriller
# 4                                    Kaali Khuhi                Mystery
# ..                                           ...                    ...
# 579        Taylor Swift: Reputation Stadium Tour           Concert Film
# 580  Winter on Fire: Ukraine's Fight for Freedom            Documentary
# 581                      Springsteen on Broadway           One-man show
# 582    Emicida: AmarElo - It's All For Yesterday            Documentary
# 583     David Attenborough: A Life on Our Planet            Documentary
#
#       Premiere  Runtime  IMDB Score                  Language  month  year  \
# 0   2019-08-05       58         2.5          English/Japanese      8  2019
# 1   2020-08-21       81         2.6                   Spanish      8  2020
# 2   2019-12-26       79         2.6                   Italian     12  2019
# 3   2018-01-19       94         3.2                   English      1  2018
# 4   2020-10-30       90         3.4                     Hindi     10  2020
# ..         ...      ...         ...                       ...    ...   ...
# 579 2018-12-31      125         8.4                   English     12  2018
# 580 2015-10-09       91         8.4  English/Ukranian/Russian     10  2015
# 581 2018-12-16      153         8.5                   English     12  2018
# 582 2020-12-08       89         8.6                Portuguese     12  2020
# 583 2020-10-04       83         9.0                   English     10  2020
#
#      day  date_day day of week
# 0      0         5         Mon
# 1      4        21         Fri
# 2      3        26       Thurs
# 3      4        19         Fri
# 4      4        30         Fri
# ..   ...       ...         ...
# 579    0        31         Mon
# 580    4         9         Fri
# 581    6        16         Sun
# 582    1         8        Tues
# 583    6         4         Sun
#
# [584 rows x 11 columns]

# %%
Mmap = {1: 'Jan',2:'Feb',3:'Mar',4:'April',5:'May',6:'Jun',7:'July',8:'Aug',9:'Sept',10:'Oct',11:'Nov',12:'Dec'}
df['month_map'] = df['month'].map(Mmap)
df
# Out:
#                                            Title                  Genre  \
# 0                                Enter the Anime            Documentary
# 1                                    Dark Forces               Thriller
# 2                                        The App  Science fiction/Drama
# 3                                 The Open House        Horror thriller
# 4                                    Kaali Khuhi                Mystery
# ..                                           ...                    ...
# 579        Taylor Swift: Reputation Stadium Tour           Concert Film
# 580  Winter on Fire: Ukraine's Fight for Freedom            Documentary
# 581                      Springsteen on Broadway           One-man show
# 582    Emicida: AmarElo - It's All For Yesterday            Documentary
# 583     David Attenborough: A Life on Our Planet            Documentary
#
#       Premiere  Runtime  IMDB Score                  Language  month  year  \
# 0   2019-08-05       58         2.5          English/Japanese      8  2019
# 1   2020-08-21       81         2.6                   Spanish      8  2020
# 2   2019-12-26       79         2.6                   Italian     12  2019
# 3   2018-01-19       94         3.2                   English      1  2018
# 4   2020-10-30       90         3.4                     Hindi     10  2020
# ..         ...      ...         ...                       ...    ...   ...
# 579 2018-12-31      125         8.4                   English     12  2018
# 580 2015-10-09       91         8.4  English/Ukranian/Russian     10  2015
# 581 2018-12-16      153         8.5                   English     12  2018
# 582 2020-12-08       89         8.6                Portuguese     12  2020
# 583 2020-10-04       83         9.0                   English     10  2020
#
#      day  date_day day of week month_map
# 0      0         5         Mon       Aug
# 1      4        21         Fri       Aug
# 2      3        26       Thurs       Dec
# 3      4        19         Fri       Jan
# 4      4        30         Fri       Oct
# ..   ...       ...         ...       ...
# 579    0        31         Mon       Dec
# 580    4         9         Fri       Oct
# 581    6        16         Sun       Dec
# 582    1         8        Tues       Dec
# 583    6         4         Sun       Oct
#
# [584 rows x 12 columns]

# %% [markdown]
# ## Visualisation

# %% [markdown]
# #### 장르 확인

# %%
df["Genre"]
# Out:
# 0                Documentary
# 1                   Thriller
# 2      Science fiction/Drama
# 3            Horror thriller
# 4                    Mystery
#                ...
# 579             Concert Film
# 580              Documentary
# 581             One-man show
# 582              Documentary
# 583              Documentary
# Name: Genre, Length: 584, dtype: object

# %%
genre = df.sort_values(
    by=["Genre"], 
    ascending=False
)[["Genre"]].drop_duplicates().reset_index()

genre
# Out:
#      index             Genre
# 0      194      Zombie/Heist
# 1      237           Western
# 2      219        War-Comedy
# 3      553         War drama
# 4      497               War
# ..     ...               ...
# 110    450   Action-thriller
# 111    507  Action-adventure
# 112    318   Action thriller
# 113     61     Action comedy
# 114     39            Action
#
# [115 rows x 2 columns]

# %% [markdown]
# ### 장르별 작품수

# %%
g = df.Genre.value_counts()[:20]
plt.figure(figsize = (32,10))
plt.xticks(rotation=90, size=15)  

g.plot(kind='bar')
# Out:
# <Axes: xlabel='Genre'>

# %% [markdown]
# ### 평점높은 장르 순위

# %%
genre_10 = df.sort_values("IMDB Score", ascending = False)[['Title','Genre', 'IMDB Score','year']][0:10]
genre_10
# Out:
#                                            Title  \
# 583     David Attenborough: A Life on Our Planet
# 582    Emicida: AmarElo - It's All For Yesterday
# 581                      Springsteen on Broadway
# 580  Winter on Fire: Ukraine's Fight for Freedom
# 579        Taylor Swift: Reputation Stadium Tour
# 578   Ben Platt: Live from Radio City Music Hall
# 577                       Dancing with the Birds
# 576                      Cuba and the Cameraman
# 573                                        Klaus
# 571                                         13th
#
#                                     Genre  IMDB Score  year
# 583                           Documentary         9.0  2020
# 582                           Documentary         8.6  2020
# 581                          One-man show         8.5  2018
# 580                           Documentary         8.4  2015
# 579                          Concert Film         8.4  2018
# 578                          Concert Film         8.4  2020
# 577                           Documentary         8.3  2019
# 576                           Documentary         8.3  2017
# 573  Animation/Christmas/Comedy/Adventure         8.2  2019
# 571                           Documentary         8.2  2016

# %%
plt.figure(figsize = (5,3))
sns.barplot(data=genre_10, x = 'IMDB Score', y = 'Genre')
# Out:
# <Axes: xlabel='IMDB Score', ylabel='Genre'>

# %% [markdown]
# ### 언어 탑10

# %%
plt.figure(figsize = (7,5))
plt.xticks(rotation=0, size=9)  
df.Language.value_counts().iloc[:10].plot(kind='barh')
# Out:
# <Axes: ylabel='Language'>

# %% [markdown]
# ### 평점 높은 작품 탑10

# %%
df.sort_values(['IMDB Score'], ascending = False)[0:10]
# Out:
#                                            Title  \
# 583     David Attenborough: A Life on Our Planet
# 582    Emicida: AmarElo - It's All For Yesterday
# 581                      Springsteen on Broadway
# 580  Winter on Fire: Ukraine's Fight for Freedom
# 579        Taylor Swift: Reputation Stadium Tour
# 578   Ben Platt: Live from Radio City Music Hall
# 577                       Dancing with the Birds
# 576                      Cuba and the Cameraman
# 573                                        Klaus
# 571                                         13th
#
#                                     Genre   Premiere  Runtime  IMDB Score  \
# 583                           Documentary 2020-10-04       83         9.0
# 582                           Documentary 2020-12-08       89         8.6
# 581                          One-man show 2018-12-16      153         8.5
# 580                           Documentary 2015-10-09       91         8.4
# 579                          Concert Film 2018-12-31      125         8.4
# 578                          Concert Film 2020-05-20       85         8.4
# 577                           Documentary 2019-10-23       51         8.3
# 576                           Documentary 2017-11-24      114         8.3
# 573  Animation/Christmas/Comedy/Adventure 2019-11-15       97         8.2
# 571                           Documentary 2016-10-07      100         8.2
#
#                      Language  month  year  day  date_day day of week  \
# 583                   English     10  2020    6         4         Sun
# 582                Portuguese     12  2020    1         8        Tues
# 581                   English     12  2018    6        16         Sun
# 580  English/Ukranian/Russian     10  2015    4         9         Fri
# 579                   English     12  2018    0        31         Mon
# 578                   English      5  2020    2        20         Wed
# 577                   English     10  2019    2        23         Wed
# 576                   English     11  2017    4        24         Fri
# 573                   English     11  2019    4        15         Fri
# 571                   English     10  2016    4         7         Fri
#
#     month_map
# 583       Oct
# 582       Dec
# 581       Dec
# 580       Oct
# 579       Dec
# 578       May
# 577       Oct
# 576       Nov
# 573       Nov
# 571       Oct

# %%
rate_10 = df.sort_values(['IMDB Score'], ascending = False)[0:10]
sns.barplot(data = rate_10, x= 'IMDB Score', y='Title')
# Out:
# <Axes: xlabel='IMDB Score', ylabel='Title'>

# %% [markdown]
# ### 영어 작품 탑10

# %%
eng_rate =df[df["Language"] == "English"][["Title","Genre","IMDB Score"]].sort_values(by= "IMDB Score", ascending=False).iloc[:10]
eng_rate
# Out:
#                                           Title  \
# 583    David Attenborough: A Life on Our Planet
# 581                     Springsteen on Broadway
# 579       Taylor Swift: Reputation Stadium Tour
# 578  Ben Platt: Live from Radio City Music Hall
# 577                      Dancing with the Birds
# 576                     Cuba and the Cameraman
# 574                                  Seaspiracy
# 573                                       Klaus
# 572           Disclosure: Trans Lives on Screen
# 571                                        13th
#
#                                     Genre  IMDB Score
# 583                           Documentary         9.0
# 581                          One-man show         8.5
# 579                          Concert Film         8.4
# 578                          Concert Film         8.4
# 577                           Documentary         8.3
# 576                           Documentary         8.3
# 574                           Documentary         8.2
# 573  Animation/Christmas/Comedy/Adventure         8.2
# 572                           Documentary         8.2
# 571                           Documentary         8.2

# %% [markdown]
# ### 한국어 작품 탑10

# %%
kor_rate = df[df["Language"] == "Korean"][["Title","Genre","IMDB Score"]].sort_values(by= "IMDB Score", ascending=False)
kor_rate
# Out:
#                            Title            Genre  IMDB Score
# 533  Blackpink: Light Up the Sky      Documentary         7.5
# 382            Night in Paradise            Drama         6.7
# 358               Space Sweepers  Science fiction         6.6
# 288                 Time to Hunt         Thriller         6.3
# 18     What Happened to Mr. Cha?           Comedy         4.3
# 11                      The Call            Drama         4.1

# %%
kor_rate = df[(df["Language"] == "English") & (df["year"] == 2020)][["Title","Genre","IMDB Score"]].sort_values(by= "IMDB Score", ascending=False)[:10]
kor_rate
# Out:
#                                           Title              Genre  IMDB Score
# 583    David Attenborough: A Life on Our Planet        Documentary         9.0
# 578  Ben Platt: Live from Radio City Music Hall       Concert Film         8.4
# 572           Disclosure: Trans Lives on Screen        Documentary         8.2
# 570                              Rising Phoenix        Documentary         8.1
# 569                          My Octopus Teacher        Documentary         8.1
# 563                               A Secret Love        Documentary         7.9
# 562                  The Trial of the Chicago 7              Drama         7.8
# 560              If Anything Happens I Love You  Animation / Short         7.8
# 555          Crip Camp: A Disability Revolution        Documentary         7.7
# 548                          The Social Dilemma        Documentary         7.6

# %%
hindi_rate = df[df["Language"] == "Hindi"][["Title","Genre","IMDB Score"]].sort_values(by= "IMDB Score", ascending=False)
hindi_rate
# Out:
#                                      Title                  Genre  IMDB Score
# 551                             Yeh Ballet                  Drama         7.6
# 543                                   Ludo  Anthology/Dark comedy         7.6
# 509                         Raat Akeli Hai               Thriller         7.3
# 491                                   Soni            Crime drama         7.2
# 486                   Love per Square Foot        Romantic comedy         7.2
# 423                               Pagglait           Comedy-drama         6.9
# 413                               AK vs AK               Thriller         6.9
# 405                            Serious Men                  Drama         6.8
# 397                   Long Live Brij Mohan                 Comedy         6.8
# 388                               Upstarts                  Drama         6.7
# 365                        Ajeeb Daastaans                  Drama         6.7
# 354                              Milestone                  Drama         6.6
# 348                                Bulbbul                 Horror         6.6
# 335                           Lust Stories                  Drama         6.5
# 327                             Chopsticks                 Comedy         6.5
# 274                          Music Teacher                  Drama         6.3
# 241          Tribhanga  Tedhi Medhi Crazy                  Drama         6.1
# 210                             Lovefucked                  Drama         6.0
# 200                                  Maska        Romantic comedy         5.9
# 176                           Rajma Chawal           Comedy-drama         5.8
# 169                           Class of '83                  Drama         5.8
# 168                Choked: Paisa Bolta Hai                  Drama         5.8
# 147                       Ginny Weds Sunny        Romantic comedy         5.7
# 112                           House Arrest                 Comedy         5.5
# 100                                 Guilty               Thriller         5.4
# 97   Dolly Kitty and Those Twinkling Stars                  Drama         5.4
# 87          Gunjan Saxena: The Kargil Girl                  Drama         5.3
# 45                      Mrs. Serial Killer               Thriller         4.8
# 23                   The Girl on the Train               Thriller         4.4
# 16                           Ghost Stories       Horror anthology         4.3
# 9                       Sardar Ka Grandson                 Comedy         4.1
# 5                                    Drive                 Action         3.5
# 4                              Kaali Khuhi                Mystery         3.4

# %%
df[df["Language"] == "English/Korean"][["Title","Genre","IMDB Score"]].sort_values(by= "IMDB Score", ascending=False)
# Out:
#     Title             Genre  IMDB Score
# 507  Okja  Action-adventure         7.3

# %%
df[df["Language"] == "Thai"][["Title","Genre","IMDB Score"]].sort_values(by= "IMDB Score", ascending=False)
# Out:
#          Title        Genre  IMDB Score
# 151   One Take  Documentary         5.7
# 71   Ghost Lab       Horror         5.2

# %%
### 평점 8점 이상 작품

# %%
rate_8 = df[df['IMDB Score']>=8]

plt.figure(figsize = (10,7))
sns.barplot(data = rate_8, x = 'IMDB Score', y = 'Title',hue ='Genre')
# Out:
# <Axes: xlabel='IMDB Score', ylabel='Title'>

# %%
### 평점 4점 이하 작품

# %%
rate_4 = df[df['IMDB Score']<=4]

plt.figure(figsize = (10,4))
sns.barplot(data = rate_4, x = 'IMDB Score', y = 'Title',hue ='Genre')
# Out:
# <Axes: xlabel='IMDB Score', ylabel='Title'>

# %%
### 연도별 작품 수

# %%
plt.figure(figsize = (5,4))
sns.countplot(
    data=df,
    x="year"
)
# Out:
# <Axes: xlabel='year', ylabel='count'>

# %%
### 연도별 평점 추이

# %%
plt.figure(figsize=(10,4))
sns.lineplot(x='year',y='IMDB Score',data=df)
# Out:
# <Axes: xlabel='year', ylabel='IMDB Score'>

# %%
### 요일별 작품 개봉

# %%
bar_order = ['Mon','Tues','Wed','Thurs','Fri','Sat','Sun']
sns.countplot(x='day of week',data=df ,order=bar_order)
# Out:
# <Axes: xlabel='day of week', ylabel='count'>

# %%
### 월별 작품 개봉 수

# %%
bar_order = ['Jan','Feb','Mar','April','May','Jun','July','Aug','Sept','Oct','Nov','Dec']
sns.countplot(x='month_map',data=df ,order=bar_order)
# Out:
# <Axes: xlabel='month_map', ylabel='count'>

# %%
random.seed(100)
labels = ['', 'B', 'C']
fig = plt.figure()
fig.set_facecolor('white')
for _, label in enumerate(labels):    
    x = df[year]  
    y = df[year].value_counts()   
sns.lineplot(x=x, y=y, label=label)
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[137], line 1
# ----> 1 random.seed(100)
#       2 labels = ['', 'B', 'C']
#       3 fig = plt.figure()
#
# NameError: name 'random' is not defined

# %%
df.groupby('Genre')[["Title"]]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[165], line 1
# ----> 1 df.groupby('Genre')[["Title"]].sort_values(by= "IMDB Score", ascending=False)[:10]
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:952, in GroupBy.__getattr__(self, attr)
#     949 if attr in self.obj:
#     950     return self[attr]
# --> 952 raise AttributeError(
#     953     f"'{type(self).__name__}' object has no attribute '{attr}'"
#     954 )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'sort_values'

# %%
df[["IMDB Score"]].groupby(df["Genre"])

# %%
### 2019년 작품 탑10

# %%
year_rate = df[df["year"] == 2019][["Title","IMDB Score","Genre"]].sort_values(by= "IMDB Score", ascending=False)[:10]
year_rate
# Out:
#                                                  Title  IMDB Score  \
# 577                             Dancing with the Birds         8.3
# 573                                              Klaus         8.2
# 565                                     Marriage Story         7.9
# 561                                       The Irishman         7.8
# 554                   Brene Brown: The Call to Courage         7.7
# 552                                              Anima         7.7
# 549                                      The Two Popes         7.6
# 546                                   Tell Me Who I Am         7.6
# 545  Rolling Thunder Revue: A bob Dylan Story by Ma...         7.6
# 539                John Mulaney & the Sack Lunch Bunch         7.5
#
#                                     Genre
# 577                           Documentary
# 573  Animation/Christmas/Comedy/Adventure
# 565                                 Drama
# 561                           Crime drama
# 554                           Documentary
# 552                       Musical / Short
# 549                                 Drama
# 546                           Documentary
# 545                           Documentary
# 539                          Variety show

# %%
### 2020 작품 탑10

# %%
year_rate = df[df["year"] == 2020][["Title","IMDB Score","Genre"]].sort_values(by= "IMDB Score", ascending=False)[:10]
year_rate
# Out:
#                                           Title  IMDB Score              Genre
# 583    David Attenborough: A Life on Our Planet         9.0        Documentary
# 582   Emicida: AmarElo - It's All For Yesterday         8.6        Documentary
# 578  Ben Platt: Live from Radio City Music Hall         8.4       Concert Film
# 575       The Three Deaths of Marisela Escobedo         8.2        Documentary
# 572           Disclosure: Trans Lives on Screen         8.2        Documentary
# 570                              Rising Phoenix         8.1        Documentary
# 569                          My Octopus Teacher         8.1        Documentary
# 563                               A Secret Love         7.9        Documentary
# 562                  The Trial of the Chicago 7         7.8              Drama
# 560              If Anything Happens I Love You         7.8  Animation / Short

# %%
### 2021 작품 탑10

# %%
year_rate = df[df["year"] == 2021][["Title","IMDB Score","Genre"]].sort_values(by= "IMDB Score", ascending=False)[:10]
year_rate
# Out:
#                                                  Title  IMDB Score  \
# 574                                         Seaspiracy         8.2
# 493                                       The Disciple         7.2
# 477                                    The White Tiger         7.1
# 475                                            The Dig         7.1
# 470                                  Pieces of a Woman         7.1
# 461                                              Ferry         7.1
# 441                                               Pele         7.0
# 440  Operation Varsity Blues: The College Admission...         7.0
# 423                                           Pagglait         6.9
# 416                      Biggie: I Got a Story to Tell         6.9
#
#             Genre
# 574   Documentary
# 493         Drama
# 477         Drama
# 475         Drama
# 470         Drama
# 461   Crime drama
# 441   Documentary
# 440   Documentary
# 423  Comedy-drama
# 416   Documentary

# %%
### 공포영화 시즌

# %%
scary_movie = df[(df["Genre"]=="Thriller") | (df["Genre"]=="Horror") | (df["Genre"]=="Zombie/Heist")][["Title","month","Language","IMDB Score"]]
scary_movie
# Out:
#                                              Title  month   Language  \
# 1                                      Dark Forces      8    Spanish
# 14                                           Mercy     11    English
# 21                                Secret Obsession      7    English
# 23                           The Girl on the Train      2      Hindi
# 25                                    Fatal Affair      7    English
# 31   I Am the Pretty Thing That Lives in the House     10    English
# 34                                     Rattlesnake     10    English
# 43                             Christmas Crossfire     12     German
# 45                              Mrs. Serial Killer      5      Hindi
# 46              Nobody Sleeps in the Woods Tonight     10     Polish
# 57                                         Rebirth      7    English
# 59                                         Cadaver     10  Norwegian
# 60                                        Clinical      1    English
# 71                                       Ghost Lab      5       Thai
# 86                                  Dangerous Lies      4    English
# 88                                       Intuition      5    Spanish
# 89        The Most Assassinated Woman in the World      9     French
# 90                             Things Heard & Seen      4    English
# 100                                         Guilty      3      Hindi
# 101                              In the Tall Grass     10    English
# 109                                      Dead Kids     12   Filipino
# 117                                        Red Dot      2    Swedish
# 130                                  Hold the Dark      9    English
# 137                                  The Paramedic      9    Spanish
# 146                                            Eli     10    English
# 154                                     Prime Time      4     Polish
# 159                                 Velvet Buzzsaw      2    English
# 172                                 I Am All Girls      5    English
# 192                              A Fall from Grace      1    English
# 194                               Army of the Dead      5    English
# 201                                    The Decline      3     French
# 242                                Unknown Origins      8    Spanish
# 251                      In the Shadow of the Moon      9    English
# 252                                    Lost Bullet      6     French
# 254                          Offering to the Storm      7    Spanish
# 288                                   Time to Hunt      4     Korean
# 298                                      Fractured     10    English
# 313                                   The Occupant      3    Spanish
# 332                                      His House     10    English
# 348                                        Bulbbul      6      Hindi
# 398                                        Calibre      6    English
# 413                                       AK vs AK     12      Hindi
# 509                                 Raat Akeli Hai      7      Hindi
#
#      IMDB Score
# 1           2.6
# 14          4.2
# 21          4.4
# 23          4.4
# 25          4.5
# 31          4.6
# 34          4.6
# 43          4.8
# 45          4.8
# 46          4.8
# 57          5.0
# 59          5.1
# 60          5.1
# 71          5.2
# 86          5.3
# 88          5.3
# 89          5.3
# 90          5.3
# 100         5.4
# 101         5.4
# 109         5.5
# 117         5.5
# 130         5.6
# 137         5.6
# 146         5.7
# 154         5.7
# 159         5.7
# 172         5.8
# 192         5.9
# 194         5.9
# 201         5.9
# 242         6.1
# 251         6.2
# 252         6.2
# 254         6.2
# 288         6.3
# 298         6.4
# 313         6.4
# 332         6.5
# 348         6.6
# 398         6.8
# 413         6.9
# 509         7.3

# %%
df[(df["Genre"]=="Psychological thriller") |(df["Genre"]=="Horror-thriller")|(df["Genre"]=="Horror thriller")][["Title","month","Language","IMDB Score"]]
# Out:
#                              Title  month Language  IMDB Score
# 3                   The Open House      1  English         3.2
# 19                      Death Note      8  English         4.4
# 157        The Woman in the Window      5  English         5.7
# 240                 The Perfection      5  English         6.1
# 265                        Apostle     10  English         6.3
# 331                  Gerald's Game      9  English         6.5
# 347                       Bird Box     12  English         6.6
# 352  I'm Thinking of Ending Things      9  English         6.6
# 474         The Devil All the Time      9  English         7.1

# %%
family_movie = df[(df["Genre"]=="Family") | (df["Genre"]=="Family film")][["Title","month","Language"]]
family_movie
# Out:
#               Title  month Language
# 52     Holiday Rush     11  English
# 144      Dad Wanted      9  Spanish
# 225  Finding 'Ohana      1  English
# 266           Benji      3  English

# %%
romcom_movie = df[(df["Genre"]=="Romantic comedy") | (df["Genre"]=="Romance")][["Title","month","Language"]]
romcom_movie
# Out:
#                                       Title  month    Language
# 12                                  Whipped      9  Indonesian
# 26                             Just Say Yes      4       Dutch
# 58                             Squared Love      2      Polish
# 67                               Desperados      7     English
# 84    A Christmas Prince: The Royal Wedding     11     English
# 91                         To Each, Her Own      6      French
# 95       A Christmas Prince: The Royal Baby     12     English
# 105     The Princess Switch: Switched Again     11     English
# 114                     Love Wedding Repeat      4     English
# 121             The Knight Before Christmas     11     English
# 129                        Falling Inn Love      8     English
# 131                        Love, Guaranteed      9     English
# 132                     One-Way to Tomorrow      6     Turkish
# 147                        Ginny Weds Sunny     10       Hindi
# 156                    The Holiday Calendar     11     English
# 162                  A California Christmas     12     English
# 163                      A Christmas Prince     11     English
# 171                       Happy Anniversary      3     English
# 173                             Let It Snow     11     English
# 175                Operation Christmas Drop     11     English
# 177                            Rich in Love      4  Portuguese
# 187                     The Kissing Booth 2      7     English
# 188                        The Perfect Date      4     English
# 190                         You've Got This     10     Spanish
# 200                                   Maska      3       Hindi
# 216                       The Kissing Booth      5     English
# 217                     The Princess Switch     11     English
# 218  To All the Boys: P.S. I Still Love You      2     English
# 238                           The Lovebirds      5     English
# 256                           Someone Great      4     English
# 264                        Alex Strangelove      6     English
# 272                    I Am Not an Easy Man      4      French
# 289     To All the Boys: Always and Forever      2     English
# 300                              Isi & Ossi      2      German
# 319                       When We First Met      2     English
# 321                   All the Bright Places      2     English
# 341                               Set It Up      6     English
# 344                                  Tramps      4     English
# 349                         Crazy About Her      2     Spanish
# 350                         Elisa & Marcela      6     Spanish
# 395                      Always Be My Maybe      5     English
# 421                      Our Souls at Night      9     English
# 428                          The Half of It      5     English
# 478       To All the Boys I've Loved Before      8     English
# 486                    Love per Square Foot      2       Hindi

# %%
doc = df[(df["Genre"]=="Documentary") & (df["year"]==2020)][["Title","IMDB Score","month"]]
doc
# Out:
#                                                Title  IMDB Score  month
# 36                                        We Are One         4.6      7
# 151                                         One Take         5.7      6
# 292                            Anelka: Misunderstood         6.4      8
# 301                John Was Trying to Contact Aliens         6.4      8
# 303         Murder to Mercy: The Cyntoia Brown Story         6.4      4
# 357                          Shawn Mendes: In Wonder         6.6     11
# 373                                     Giving Voice         6.7     12
# 375               Hope Frozen: A Quest to Live Twice         6.7      9
# 392    A Life of Speed: The Juan Manuel Fangio Story         6.8      3
# 393                          A Love Song for Latasha         6.8      9
# 396                                         Becoming         6.8      5
# 400                              GIMS: On the Record         6.8      9
# 401     Have a Good Trip: Adventures in Psychedelics         6.8      5
# 415                     Bigflo & Oil: Hip Hop Frenzy         6.9     10
# 426                               Spelling the Dream         6.9      6
# 427                           The Claudia Kishi Club         6.9      7
# 455                                  Circus of Books         7.1      4
# 456           Dance Dreams: Hot Chocolate Nutcracker         7.1     11
# 463              Guillermo Vilas: Settling the Score         7.1     10
# 473                                Rooting for Roona         7.1     10
# 479            American Murder: The Family Next Door         7.2      9
# 484                                     LA Originals         7.2      4
# 502                               Father Soldier Son         7.3      7
# 505  Mucho Mucho Amor: The Legend of Walter Mercado          7.3      7
# 512                      Secrets of the Saqqara Tomb         7.3     10
# 523                                   Miss Americana         7.4      1
# 529                                 The Speed Cubers         7.4      7
# 533                      Blackpink: Light Up the Sky         7.5     10
# 535                             Dick Johnson Is Dead         7.5     10
# 542                                        Athlete A         7.6      6
# 548                               The Social Dilemma         7.6      9
# 555               Crip Camp: A Disability Revolution         7.7      3
# 563                                    A Secret Love         7.9      4
# 569                               My Octopus Teacher         8.1      9
# 570                                   Rising Phoenix         8.1      8
# 572                Disclosure: Trans Lives on Screen         8.2      6
# 575            The Three Deaths of Marisela Escobedo         8.2     10
# 582        Emicida: AmarElo - It's All For Yesterday         8.6     12
# 583         David Attenborough: A Life on Our Planet         9.0     10

# %% [markdown]
# ### 연속형 데이터 - Runtime

# %%
df["Runtime"].describe()
# Out:
# count    584.000000
# mean      93.577055
# std       27.761683
# min        4.000000
# 25%       86.000000
# 50%       97.000000
# 75%      108.000000
# max      209.000000
# Name: Runtime, dtype: float64

# %%
df['Runtime'].plot(
    kind="hist",
    bins=np.arange(0,200,10)
)
plt.xlabel('Runtime')
# Out:
# Text(0.5, 0, 'Runtime')

# %%
sns.displot(df['Runtime'])
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
plt.boxplot(df['Runtime'], labels=['Runtime'], vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x232ab014410>,
#   <matplotlib.lines.Line2D at 0x232ac095dd0>],
#  'caps': [<matplotlib.lines.Line2D at 0x232a87c1510>,
#   <matplotlib.lines.Line2D at 0x232ac0b4150>],
#  'boxes': [<matplotlib.lines.Line2D at 0x232ac0a9890>],
#  'medians': [<matplotlib.lines.Line2D at 0x232ac0b4d50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x232ac0b4190>],
#  'means': []}

# %% [markdown]
# ### 연속형 데이터- IMDB Score

# %%
df["IMDB Score"].describe()
# Out:
# count    584.000000
# mean       6.271747
# std        0.979256
# min        2.500000
# 25%        5.700000
# 50%        6.350000
# 75%        7.000000
# max        9.000000
# Name: IMDB Score, dtype: float64

# %%
df["IMDB Score"].plot(
    kind="hist",
    bins=np.arange(2,10,0.2)
)
plt.xlabel("IMDB Score")
# Out:
# Text(0.5, 0, 'IMDB Score')

# %%
sns.displot(df['IMDB Score'])
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
plt.boxplot(df['IMDScore'], labels=['IMDB Score'], vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x232a8677450>,
#   <matplotlib.lines.Line2D at 0x232ac284c10>],
#  'caps': [<matplotlib.lines.Line2D at 0x232ac285390>,
#   <matplotlib.lines.Line2D at 0x232ac285e90>],
#  'boxes': [<matplotlib.lines.Line2D at 0x232ac273350>],
#  'medians': [<matplotlib.lines.Line2D at 0x232ac286910>],
#  'fliers': [<matplotlib.lines.Line2D at 0x232ac2873d0>],
#  'means': []}

# %% [markdown]
# ### 평점 & 런타임 상관관계

# %%
rate_time =df[['Runtime','IMDB Score']]

sns.scatterplot(data=rate_time, x='IMDB Score', y='Runtime')
# Out:
# <Axes: xlabel='IMDB Score', ylabel='Runtime'>

# %%
sns.heatmap(rate_time.corr(), annot = True)
# Out:
# <Axes: >

# %% [markdown]
# ### 데이터 pairplot 그려보기

# %%
sns.pairplot(df)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
plt.boxplot(df['Runtime'], labels=['IMDB Score'], vert=False)

# %%
df[df["Runtime"]<= 50]["IMDB Score"].plot(kind="box")
# Out:
# <Axes: >

# %%
df[df["Runtime"]>50 & (df["Runtime"] <= 100)]["IMDB Score"].plot(kind="box")
# Out:
# <Axes: >

# %%
df[df["Runtime"] <= 50]
# Out:
#                                                  Title                  Genre  \
# 15                                      After the Raid            Documentary
# 30                                         After Maria            Documentary
# 33    Porta dos Fundos: The First Temptation of Christ                 Comedy
# 40                                         Sol Levante          Anime / Short
# 66   American Factory: A Conversation with the Obamas   Aftershow / Interview
# 111                               Ghosts of Sugar Land            Documentary
# 133                    Sarah Cooper: Everything's Fine           Variety show
# 152                                   Out of Many, One            Documentary
# 197     Frankenstein's Monster's Monster, Frankenstein           Mockumentary
# 199  Notes from Dunblane: Lesson from a School Shoo...            Documentary
# 244                                         Alien Xmas            Stop Motion
# 263                             A Tale of Two Kitchens            Documentary
# 278                Porta dos Fundos: The Last Hangover                 Comedy
# 295                                            Birders            Documentary
# 301                  John Was Trying to Contact Aliens            Documentary
# 309            Sturgill Simpson Presents: Sound & Fury   Animation / Musicial
# 320                                     A 3 Minute Hug            Documentary
# 325                                            Canvas       Animation / Short
# 326            Chadwick Boseman: Portrait of an Artist            Documentary
# 334                                  Life Overtakes Me            Documentary
# 345                                  What Did Jack Do?          Drama / Short
# 363                        What Would Sophia Loren Do?            Documentary
# 378                                   Little Miss Sumo            Documentary
# 393                            A Love Song for Latasha            Documentary
# 394                                   All in My Family            Documentary
# 402                                         Heroin(e)             Documentary
# 407           The Boys in the Band: Something Personal  Aftershow / Interview
# 410                                         The Trader            Documentary
# 417                                   Cops and Robbers      Animation / Short
# 427                             The Claudia Kishi Club            Documentary
# 430  The Lonely Island Presents: The Unauthorized B...       Comedy / Musical
# 434  I'm No Longer Here: A Discussion with Guillerm...  Aftershow / Interview
# 436                         Lorena, Light-Footed Woman            Documentary
# 439  Ma Rainey's Black Bottom: A Legacy Brought to ...  Aftershow / Interview
# 442                ReMastered: Devil at the Crossroads            Documentary
# 445                                          Resurface            Documentary
# 446                  Rocko's Modern Life: Static Cling     Animation / Comedy
# 451  13th: A Conversation with Oprah Winfrey & Ava ...  Aftershow / Interview
# 452                                 Angela's Christmas              Animation
# 453                            Angela's Christmas Wish              Animation
# 457                            Derren Brown: Sacrifice      Mentalism special
# 459                                           End Game            Documentary
# 471                               Ram Dass, Going Home            Documentary
# 473                                  Rooting for Roona            Documentary
# 485                                       Ladies First            Documentary
# 496        The Road to El Camino: A Breaking Bad Movie              Making-of
# 498                                              Zion             Documentary
# 501                                           Extremis            Documentary
# 506                 Octonauts & the Great Barrier Reef              Animation
# 513                            Sitara: Let Girls Dream      Animation / Short
# 521                                   Fire in Paradise            Documentary
# 522                                          Long Shot            Documentary
# 524                           Period. End of Sentence.            Documentary
# 528                      The Irishman: In Conversation  Aftershow / Interview
# 529                                   The Speed Cubers            Documentary
# 541                                  The White Helmets            Documentary
# 552                                              Anima        Musical / Short
# 560                     If Anything Happens I Love You      Animation / Short
#
#       Premiere  Runtime  IMDB Score          Language  month  year  day  \
# 15  2019-12-19       25         4.3           Spanish     12  2019    3
# 30  2019-05-24       37         4.6   English/Spanish      5  2019    4
# 33  2019-12-03       46         4.6        Portuguese     12  2019    1
# 40  2020-04-02        4         4.7           English      4  2020    3
# 66  2019-08-21       10         5.2           English      8  2019    2
# 111 2019-10-16       21         5.5           English     10  2019    2
# 133 2020-10-27       49         5.6           English     10  2020    1
# 152 2018-12-12       34         5.7           English     12  2018    2
# 197 2019-07-16       32         5.9           English      7  2019    1
# 199 2018-09-28       23         5.9           English      9  2018    4
# 244 2020-11-20       42         6.2           English     11  2020    4
# 263 2019-05-22       30         6.3   English/Spanish      5  2019    2
# 278 2018-12-21       44         6.3        Portuguese     12  2018    4
# 295 2019-09-25       37         6.4   English/Spanish      9  2019    2
# 301 2020-08-20       16         6.4           English      8  2020    3
# 309 2019-09-27       41         6.4           English      9  2019    4
# 320 2019-10-28       28         6.5   English/Spanish     10  2019    0
# 325 2020-12-11        9         6.5           English     12  2020    4
# 326 2021-04-17       21         6.5           English      4  2021    5
# 334 2019-06-14       40         6.5   English/Swedish      6  2019    4
# 345 2020-01-20       17         6.5           English      1  2020    0
# 363 2021-01-15       32         6.6           English      1  2021    4
# 378 2019-10-28       19         6.7          Japanese     10  2019    0
# 393 2020-09-21       19         6.8           English      9  2020    0
# 394 2019-05-03       39         6.8  English/Mandarin      5  2019    4
# 402 2017-09-12       39         6.8           English      9  2017    1
# 407 2020-09-30       28         6.8           English      9  2020    2
# 410 2018-02-09       23         6.8          Georgian      2  2018    4
# 417 2020-12-28        7         6.9           English     12  2020    0
# 427 2020-07-10       17         6.9           English      7  2020    4
# 430 2019-05-23       30         6.9           English      5  2019    3
# 434 2020-11-03       14         7.0           English     11  2020    1
# 436 2019-11-20       28         7.0           Spanish     11  2019    2
# 439 2020-12-18       31         7.0           English     12  2020    4
# 442 2019-04-26       48         7.0           English      4  2019    4
# 445 2017-09-01       27         7.0           English      9  2017    4
# 446 2019-08-09       45         7.0           English      8  2019    4
# 451 2017-01-26       36         7.1           English      1  2017    3
# 452 2018-11-30       30         7.1           English     11  2018    4
# 453 2020-12-01       47         7.1           English     12  2020    1
# 457 2018-10-19       49         7.1           English     10  2018    4
# 459 2018-05-04       40         7.1           English      5  2018    4
# 471 2018-04-06       31         7.1           English      4  2018    4
# 473 2020-10-15       41         7.1           Bengali     10  2020    3
# 485 2018-03-08       39         7.2     English/Hindi      3  2018    3
# 496 2019-10-29       13         7.2           English     10  2019    1
# 498 2018-08-10       11         7.2           English      8  2018    4
# 501 2016-09-13       24         7.3           English      9  2016    1
# 506 2020-10-13       47         7.3           English     10  2020    1
# 513 2020-03-08       15         7.3           English      3  2020    6
# 521 2019-11-01       39         7.4           English     11  2019    4
# 522 2017-09-29       40         7.4           English      9  2017    4
# 524 2019-02-12       26         7.4     English/Hindi      2  2019    1
# 528 2019-11-27       23         7.4           English     11  2019    2
# 529 2020-07-29       40         7.4           English      7  2020    2
# 541 2016-09-16       40         7.5           English      9  2016    4
# 552 2019-06-27       15         7.7           English      6  2019    3
# 560 2020-11-20       12         7.8           English     11  2020    4
#
#      date_day day of week month_map
# 15         19       Thurs       Dec
# 30         24         Fri       May
# 33          3        Tues       Dec
# 40          2       Thurs     April
# 66         21         Wed       Aug
# 111        16         Wed       Oct
# 133        27        Tues       Oct
# 152        12         Wed       Dec
# 197        16        Tues      July
# 199        28         Fri      Sept
# 244        20         Fri       Nov
# 263        22         Wed       May
# 278        21         Fri       Dec
# 295        25         Wed      Sept
# 301        20       Thurs       Aug
# 309        27         Fri      Sept
# 320        28         Mon       Oct
# 325        11         Fri       Dec
# 326        17         Sat     April
# 334        14         Fri       Jun
# 345        20         Mon       Jan
# 363        15         Fri       Jan
# 378        28         Mon       Oct
# 393        21         Mon      Sept
# 394         3         Fri       May
# 402        12        Tues      Sept
# 407        30         Wed      Sept
# 410         9         Fri       Feb
# 417        28         Mon       Dec
# 427        10         Fri      July
# 430        23       Thurs       May
# 434         3        Tues       Nov
# 436        20         Wed       Nov
# 439        18         Fri       Dec
# 442        26         Fri     April
# 445         1         Fri      Sept
# 446         9         Fri       Aug
# 451        26       Thurs       Jan
# 452        30         Fri       Nov
# 453         1        Tues       Dec
# 457        19         Fri       Oct
# 459         4         Fri       May
# 471         6         Fri     April
# 473        15       Thurs       Oct
# 485         8       Thurs       Mar
# 496        29        Tues       Oct
# 498        10         Fri       Aug
# 501        13        Tues      Sept
# 506        13        Tues       Oct
# 513         8         Sun       Mar
# 521         1         Fri       Nov
# 522        29         Fri      Sept
# 524        12        Tues       Feb
# 528        27         Wed       Nov
# 529        29         Wed      July
# 541        16         Fri      Sept
# 552        27       Thurs       Jun
# 560        20         Fri       Nov

# %%
df.groupby(["Language"])[["IMDB Score", "Runtime"]].mean()
# Out:
#                             IMDB Score     Runtime
# Language
# Bengali                       7.100000   41.000000
# Dutch                         5.800000   99.666667
# English                       6.380050   91.817955
# English/Akan                  7.700000  136.000000
# English/Arabic                7.300000  114.000000
# English/Hindi                 7.300000   32.500000
# English/Japanese              4.400000   89.000000
# English/Korean                7.300000  121.000000
# English/Mandarin              7.050000   59.000000
# English/Russian               7.300000   90.000000
# English/Spanish               6.220000   39.200000
# English/Swedish               6.500000   40.000000
# English/Taiwanese/Mandarin    6.500000   91.000000
# English/Ukranian/Russian      8.400000   91.000000
# Filipino                      5.100000   99.500000
# French                        5.770000   92.700000
# Georgian                      6.800000   23.000000
# German                        5.640000   99.600000
# Hindi                         5.981818  115.787879
# Indonesian                    5.844444  103.777778
# Italian                       5.542857   98.357143
# Japanese                      6.400000   99.333333
# Khmer/English/French          7.200000  136.000000
# Korean                        5.916667  115.833333
# Malay                         4.200000  101.000000
# Marathi                       6.066667  121.666667
# Norwegian                     5.100000   86.000000
# Polish                        5.166667   98.666667
# Portuguese                    6.216667   91.250000
# Spanish                       6.303226   93.387097
# Spanish/Basque                5.600000   89.000000
# Spanish/Catalan               6.400000  116.000000
# Spanish/English               7.300000   96.000000
# Swedish                       5.500000   86.000000
# Tamil                         7.200000  101.000000
# Thai                          5.450000  101.000000
# Thia/English                  6.700000   80.000000
# Turkish                       5.660000  101.800000

# %% [markdown]
# ## Insight

# %% [markdown]
# <의외인 점>
#
# - 힌디어 2위 => 인구수, 자본에 근거했을 것이다
#
# - 영어작품에 다큐가 대부분, 근데 한국은 드라마가 강세 => 아무래도 문화적 차이가 아닌가...다양한 걸 시도하는 문화? 아니면 자본일 수도..
#         -> 혹시,,,,서양권은 불륜과 같은 주제에 별 감흥?이 없어서 그런 게 아닌가
#         -> 문화적 차이가 맞는듯ㅇㅇ(+기사 첨부하면 좋을 듯)
#
# - 요일 => 금요일에 많이 개봉하는 이유? -> 미국 기준으로 하면 토요일이긴 함
#
# - 아쉬운점 -> 2년 전에 업데이트가 끝난 데이터라 한국 데이터가 너무 부족함ㅠ
#
# - 호러 => 한국 기준으로 여름(6-8월)에 많이 나올 거라고 예상했는데 10월에 가장 많았음
#         -> 서양은 할로윈을 챙기니까 10월에 호러 영화가 많이 나온게 아닌가 예상함
#
#
# - 개봉작 수 => 20년에비해 21년에 개봉한 작품수는 절반 이상 차이남 -> 21년 6월까지 집계한 데이터라 하반기 개봉은 들어가지 않았음(근데 그래도 20년 개봉수는 못 따라갈 듯?)
#
#
# - 장르 => 서양권은 다큐가 많고, 보수국가에서는 드라마가 많다 -> 약간 도파민에 중독되다 못해 절여진 뇌 때문이지 않을까..자극적인 주제에 대한 문화적 차이이지 않을까 예상함
#
#
# - 공중파에서는 내보내지 못하는 제약사항들이 OTT 플랫폼에서는 제약사항이 희미해지기때문에 그런게 아닐까-

# %% [markdown]
# ## T-test

# %% [markdown]
# <T-test 주제>
#
# (1-1) 19년도와 20년도 런타임 평균 차이 -> 차이가 있다 (20년도에 작품 수가 많아서, 코로나 장기화 때문에? )
#
# (1-2) 19년도와 20년도 점수 평균 차이 -> 차이가 없다  ()
#
# (2-1) 영어 - 힌디 점수 평균 차이 -> 차이가 있다
#
# (2-2) 영어 - 힌디 런타임 평균 차이 -> 차이가 있다
#
# (3-1) 다큐 - 드라마 런타임/점수 평균 차이 -> 차이가 있다
#
# (3-2) 상/하반기 점수 평균 차이 -> 차이가 없다

# %% [markdown]
# ### two-sample_t_test로 English & Hindi 그룹의 평점 평균 차이 추정하기

# %%
df.groupby(["Language"])[["IMDB Score"]].mean()
# Out:
#                             IMDB Score
# Language
# Bengali                       7.100000
# Dutch                         5.800000
# English                       6.380050
# English/Akan                  7.700000
# English/Arabic                7.300000
# English/Hindi                 7.300000
# English/Japanese              4.400000
# English/Korean                7.300000
# English/Mandarin              7.050000
# English/Russian               7.300000
# English/Spanish               6.220000
# English/Swedish               6.500000
# English/Taiwanese/Mandarin    6.500000
# English/Ukranian/Russian      8.400000
# Filipino                      5.100000
# French                        5.770000
# Georgian                      6.800000
# German                        5.640000
# Hindi                         5.981818
# Indonesian                    5.844444
# Italian                       5.542857
# Japanese                      6.400000
# Khmer/English/French          7.200000
# Korean                        5.916667
# Malay                         4.200000
# Marathi                       6.066667
# Norwegian                     5.100000
# Polish                        5.166667
# Portuguese                    6.216667
# Spanish                       6.303226
# Spanish/Basque                5.600000
# Spanish/Catalan               6.400000
# Spanish/English               7.300000
# Swedish                       5.500000
# Tamil                         7.200000
# Thai                          5.450000
# Thia/English                  6.700000
# Turkish                       5.660000

# %%
df[(df["Language"] == "English")][["IMDB Score"]].mean()
# Out:
# IMDB Score    6.38005
# dtype: float64

# %%
df[(df["Language"] == "Hindi")][["IMDB Score"]].mean()
# Out:
# IMDB Score    5.981818
# dtype: float64

# %% [markdown]
# ## (2-1)
#
# $$H0$$ 귀무가설: 영어로 제작된 넷플릭스 작품의 IMDB Score 평균과 힌디어로 제작된 넷플릭스 작품의 IMDB Score 평균 차이는 0이다.
#
# $$Ha$$ 대립가설: 영어로 제작된 넷플릭스 작품의 IMDB Score 평균과 힌디어로 제작된 넷플릭스 작품의 IMDB Score 평균 차이는 0이 아니다.

# %% [markdown]
# ### 등분산으로 두 집단의 분산이 같은지 확인

# %%
# !pip install scipy
from scipy import stats

test_names = ["IMDB Score"]

eng_scores = df[df["Language"] == "English"][["IMDB Score"]]
hindi_scores = df[df["Language"] == "Hindi"][["IMDB Score"]]
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scipy in c:\programdata\anaconda3\lib\site-packages (1.11.1)
# Requirement already satisfied: numpy<1.28.0,>=1.21.6 in c:\programdata\anaconda3\lib\site-packages (from scipy) (1.24.3)

# %%
for test_name in test_names:
    statistic, pvalue = stats.levene(eng_scores[test_name], hindi_scores[test_name])
    if pvalue > 0.05:
        print(f"{test_name} pvalue: {pvalue} 등분산 가정 만족")
    else:
        print(f"{test_name} pvalue: {pvalue} 이분산 가정 만족")
# Out:
# IMDB Score pvalue: 0.12650211988004256 등분산 가정 만족

# %% [markdown]
# ### 양측검정 t-test

# %%
for test_name in test_names:  
    t_statistic, pvalue = stats.ttest_ind(      
    a = eng_scores[test_name],
    b = hindi_scores[test_name],
        alternative = "two-sided",    
        equal_var = True             
    )
    if pvalue < 0.05:
        print(test_name, pvalue, "귀무가설 기각")
    else:
        print(test_name, pvalue, "귀무가설 기각 불가")
# Out:
# IMDB Score 0.018069971076977442 귀무가설 기각

# %%
# 단측검정 ttest
for test_name in test_names:
    t_statistic, pvalue = stats.ttest_ind(     
    a = eng_scores[test_name],
    b = hindi_scores[test_name],
        alternative = "greater",    # 단측검정 (a > b)
        equal_var = True           
    )
    if pvalue < 0.05:
        print(test_name, pvalue, "귀무가설 기각")
    else:
        print(test_name, pvalue, "귀무가설 기각 불가")
# Out:
# IMDB Score 0.009034985538488721 귀무가설 기각

# %% [markdown]
# ### => 영어 작품의 평균 점수는 힌디어 작품의 평균 점수보다 같지 않고 통계적으로 유의하게 더 높다

# %% [markdown]
# ## (2-2)
#
# $$H0$$ 귀무가설: 영어로 제작된 넷플릭스 작품의 Runtime 평균과 힌디어로 제작된 넷플릭스 작품의 Runtime 평균 차이는 0이다.
#
# $$Ha$$ 대립가설: 영어로 제작된 넷플릭스 작품의 Runtime 평균과 힌디어로 제작된 넷플릭스 작품의 Runtime 평균 차이는 0이 아니다.

# %%
df[(df["Language"] == "English")][["Runtime"]].mean()
# Out:
# Runtime    91.817955
# dtype: float64

# %%
df[(df["Language"] == "Hindi")][["Runtime"]].mean()
# Out:
# Runtime    115.787879
# dtype: float64

# %%
test_names = ["Runtime"]

eng_runtime = df[df["Language"] == "English"][["Runtime"]]
hindi_runtime = df[df["Language"] == "Hindi"][["Runtime"]]

# %%
for test_name in test_names:
    statistic, pvalue = stats.levene(eng_runtime[test_name], hindi_runtime[test_name])
    if pvalue > 0.05:
        print(f"{test_name} pvalue: {pvalue} 등분산 가정 만족")
    else:
        print(f"{test_name} pvalue: {pvalue} 이분산 가정 만족")
# Out:
# Runtime pvalue: 0.10865288787617979 등분산 가정 만족

# %%
for test_name in test_names:  
    t_statistic, pvalue = stats.ttest_ind(      
    a = eng_runtime[test_name],
    b = hindi_runtime[test_name],
        alternative = "two-sided",    
        equal_var = True             
    )
    if pvalue < 0.05:
        print(test_name, pvalue, "귀무가설 기각")
    else:
        print(test_name, pvalue, "귀무가설 기각 불가")
# Out:
# Runtime 2.6701178942994375e-06 귀무가설 기각

# %%
# 단측검정 ttest
for test_name in test_names:
    t_statistic, pvalue = stats.ttest_ind(     
    a = hindi_runtime[test_name],
    b = eng_runtime[test_name],
        alternative = "greater",    # 단측검정 (a > b)
        equal_var = True         
    )
    if pvalue < 0.05:
        print(test_name, pvalue, "귀무가설 기각")
    else:
        print(test_name, pvalue, "귀무가설 기각 불가")
# Out:
# Runtime 1.3350589471497188e-06 귀무가설 기각

# %% [markdown]
# ### => 힌디어 작품의 런타임 평균은 영어 작품의 런타임 평균과 같지 않고 유의하게 더 높다

# %% [markdown]
# ## (4-1)
#
# $$H0$$ 귀무가설: 영어로 제작된 다큐멘터리 작품의 IMDB Score 평균과 힌디어로 제작된 드라마 작품의 IMDB Score 평균 차이는 0이다.
#
# $$Ha$$ 대립가설: 영어로 제작된 다큐멘터리 작품의 IMDB Score 평균과 힌디어로 제작된 드라마 작품의 IMDB Score 평균 차이는 0이 아니다.

# %%
df[(df["Language"] == "English") & (df["Genre"] == "Documentary")][["IMDB Score"]].mean()
# Out:
# IMDB Score    7.016667
# dtype: float64

# %%
df[(df["Language"] == "Hindi") & (df["Genre"] == "Drama")][["IMDB Score"]].mean()
# Out:
# IMDB Score    6.276923
# dtype: float64

# %%
test_names = ["IMDB Score"]

doc_scores = df[(df["Language"] == "English") & (df["Genre"] == "Documentary")][["IMDB Score"]]
drama_scores = df[(df["Language"] == "Hindi") & (df["Genre"] == "Drama")][["IMDB Score"]]

# %%
for test_name in test_names:
    statistic, pvalue = stats.levene(doc_scores[test_name], drama_scores[test_name])
    if pvalue > 0.05:
        print(f"{test_name} pvalue: {pvalue} 등분산 가정 만족")
    else:
        print(f"{test_name} pvalue: {pvalue} 이분산 가정 만족")
# Out:
# IMDB Score pvalue: 0.9000617830173057 등분산 가정 만족

# %%
for test_name in test_names:  
    t_statistic, pvalue = stats.ttest_ind(      
    a = doc_scores[test_name],
    b = drama_scores[test_name],
        alternative = "two-sided",    
        equal_var = True             
    )
    if pvalue < 0.05:
        print(test_name, pvalue, "귀무가설 기각")
    else:
        print(test_name, pvalue, "귀무가설 기각 불가")
# Out:
# IMDB Score 0.0005633622824446992 귀무가설 기각

# %%
# 단측검정 ttest
for test_name in test_names:
    t_statistic, pvalue = stats.ttest_ind(     
    a = doc_scores[test_name],
    b = drama_scores[test_name],
        alternative = "greater",    # 단측검정 (a > b)
        equal_var = True         
    )
    if pvalue < 0.05:
        print(test_name, pvalue, "귀무가설 기각")
    else:
        print(test_name, pvalue, "귀무가설 기각 불가")
# Out:
# IMDB Score 0.0002816811412223496 귀무가설 기각

# %% [markdown]
# ### => 영어 다큐멘터리 작품의 점수 평균은 힌디어 드라마 작품의 점수 평균과 같지 않고 유의하게 더 높다
