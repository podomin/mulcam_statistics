# %% [markdown]
# # ch3. numpy 난수 생성
#
# numpy를 이용하여 난수를 생성할 수 있습니다. 그냥 난수를 생성할 수도 있지만 확률 분포를 지정해서 난수를 생성할 수도 있습니다. 이번 챕터에서는 numpy가 제공하는 난수 생성 기능을 사용해보면서 확률 분포 개념을 익혀보겠습니다.

# %%
import numpy as np

np.random.seed(1234)

# %% [markdown]
# ## 확률 변수와 확률 분포
# 우리가 생성하고자 하는 random 난수는 특정한 확률에 의해서 값이 결정됩니다. 이를 확률 변수라고 부릅니다. 확률변수가 취할 수 있는 값을 확률에 대응시켜주는 함수를 확률 분포(probability distribution)라고 합니다. 더 쉽게 말하면 확률 변수들이 어떠한 형태로 놓여있을까, 어떻게 분포해 있을까를 나타내주는 함수입니다. 우리가 여러번 들어본 정규 분포가 가장 많이 쓰이는 확률 분포입니다.
#
# ### Uniform Distribution
# uniform distribution은 확률 변수가 값을 가질 수 있는 모든 구간에서 동일한 확률을 갖는 것을 의미합니다. 가령, a와 b 구간에서 무작위의 수를 갖는 확률 분포는 아래와 갖습니다. 모든 경우에 동일한 확률 값을 가지므로 선분 형태를 보입니다.

# %% [markdown]
# ![image.png](attachment:46e68077-be00-4a6e-a912-2fb156001f79.png)

# %% [markdown]
# ### Normal Distribution
# normal distribution(정규 분포)는 평균을 중심으로 종 모양의 형태를 갖습니다. 정규분포의 형태는 평균과 표준 편차에 의해서 결정됩니다. 평균을 중심으로 좌우 대칭인 종모양을 가지고, 표준편차가 클 수록 완만하게 퍼져있는 형태를 갖습니다. 정규 분포 중에서도 평균이 0, 표준 편차가 1인 정규 분포를 표준 정규 분포라고 부릅니다.

# %% [markdown]
# ![image.png](attachment:30860ba8-d566-46fb-8cfe-7f49ec573894.png)

# %% [markdown]
# ## Numpy를 이용한 난수 생성
# numpy random 모듈을 이용하면 난수를 생성할 수 있습니다. 이 때, 특정 확률 분포에 따라서 난수를 생성할 수 있습니다.

# %% [markdown]
# ### np.random.random
# np.random.random을 호출하면 파라미터로 전달한 개수만큼 0과 1 사이 구간에서 uniform distribution에 따라서 난수를 생성합니다. 직접 생성해보고, 결과를 히스토그램으로 그려보겠습니다.

# %%
from matplotlib import pyplot as plt
plt.hist(np.random.random(1000000), bins=np.arange(0,1.05,0.05))
# Out:
# (array([50070., 49793., 50171., 49909., 49920., 50324., 49869., 49785.,
#         50112., 50075., 50037., 50003., 49987., 50141., 49966., 49748.,
#         49677., 49857., 50244., 50312.]),
#  array([0.  , 0.05, 0.1 , 0.15, 0.2 , 0.25, 0.3 , 0.35, 0.4 , 0.45, 0.5 ,
#         0.55, 0.6 , 0.65, 0.7 , 0.75, 0.8 , 0.85, 0.9 , 0.95, 1.  ]),
#  <BarContainer object of 20 artists>)

# %% [markdown]
# 난수를 많이 생성할 수록 모든 구간에서 균일한 개수의 난수가 생성되는 것을 확인할 수 있습니다.

# %%
# 모든 구간에서 확률이 동일해지는 것을 알 수 있음

# %% [markdown]
# ### np.random.randn
#
# np.random.randn을 호출하면 파라미터로 전달받은 개수만큼 평균이 0, 표준 편차가 1인 표준 정규 분포에 따라서 난수를 생성합니다. 0을 중심으로 종모양으로 퍼져있기 때문에 난수 값이 음수가 될 수 도 있습니다.

# %%
plt.hist(np.random.randn(1000000), bins=np.arange(-5,5,0.05))
# Out:
# (array([0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         1.0000e+00, 0.0000e+00, 1.0000e+00, 1.0000e+00, 2.0000e+00,
#         0.0000e+00, 0.0000e+00, 1.0000e+00, 4.0000e+00, 1.0000e+00,
#         0.0000e+00, 3.0000e+00, 2.0000e+00, 3.0000e+00, 5.0000e+00,
#         9.0000e+00, 6.0000e+00, 7.0000e+00, 1.6000e+01, 1.7000e+01,
#         1.7000e+01, 2.3000e+01, 1.8000e+01, 4.5000e+01, 4.2000e+01,
#         4.3000e+01, 5.9000e+01, 7.2000e+01, 9.0000e+01, 8.4000e+01,
#         1.0700e+02, 1.3200e+02, 1.5800e+02, 1.7800e+02, 2.1300e+02,
#         2.1600e+02, 2.7000e+02, 3.3300e+02, 3.8100e+02, 4.4100e+02,
#         4.9700e+02, 5.5500e+02, 6.6100e+02, 7.4600e+02, 8.8900e+02,
#         9.4700e+02, 1.0470e+03, 1.1530e+03, 1.3110e+03, 1.4980e+03,
#         1.6940e+03, 1.8000e+03, 2.1430e+03, 2.2770e+03, 2.5270e+03,
#         2.7860e+03, 3.1280e+03, 3.4210e+03, 3.7570e+03, 4.1390e+03,
#         4.6830e+03, 4.8660e+03, 5.3610e+03, 5.6990e+03, 6.1490e+03,
# ...

# %%
_= plt.hist(np.random.randn(1000000), bins=np.arange(-5,5,0.05))

# %% [markdown]
# 난수를 많이 생성할 수록 점점 더 종모양을 닮아가는 것을 확인 할 수 있습니다.
